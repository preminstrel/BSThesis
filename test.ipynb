# %% [markdown]
# # Model

# %% [markdown]
# ## Single Task

# %%
#landmarks_frame = pd.read_csv('/mnt/data3_ssd/RetinalDataset/ODIR-5K/label_v3.csv')
import os, csv
import numpy as np


img = os.listdir('/mnt/data3_ssd/RetinalDataset/ODIR-5K/train')

public = ['N', 'D', 'G', 'C', 'A', 'H', 'M', 'O']
content = []
with open('/mnt/data3_ssd/RetinalDataset/ODIR-5K/label_v3.csv', 'r', encoding='utf-8') as f:
    csv_reader = csv.reader(f)
    for idx, c in enumerate(csv_reader):
        if idx == 0:
            content.append([c[0]] + public)
        else:
            name = c[0]
            for i in img:
                if i == name + '.jpg':
                    disease = np.array(c[1:], dtype=int)
                    content.append([name] + list(disease))
                    break
            

with open('/mnt/data3_ssd/RetinalDataset/ODIR-5K/label_train.csv', 'w', encoding='utf-8', newline='') as f:
    csv_writer = csv.writer(f)
    csv_writer.writerows(content)

# %%
landmarks_frame = pd.read_csv('/mnt/data3_ssd/RetinalDataset/RFMiD/RFMiD_Training_Labels.csv')
len(landmarks_frame)
# Out:
# 1920

# %%
idx = 1
np.array(landmarks_frame.iloc[idx, 1:]).shape
# Out:
# (46,)

# %%
landmarks_frame.iloc[idx, 0]
# Out:
# 2

# %%
import csv
import numpy as np
import pandas as pd
import os

#landmarks_frame = pd.read_csv('/mnt/data3_ssd/RetinalDataset/ODIR-5K/label_v3.csv')
img = os.listdir('/mnt/data3_ssd/RetinalDataset/ODIR-5K/valid')
len(img) # 694
public = ['N', 'D', 'G', 'C', 'A', 'H', 'M', 'O']
content = []
with open('/mnt/data3_ssd/RetinalDataset/ODIR-5K/label_v3.csv', 'r', encoding='utf-8') as f:
    csv_reader = csv.reader(f)
    for idx, c in enumerate(csv_reader):
        if idx == 0:
            content.append([c[0]] + public)
        else:
            name = c[0]
            for i in img:
                if i == name + '.jpg':
                    disease = np.array(c[1:], dtype=int)
                    content.append([name] + list(disease))
                    break
            

with open('/mnt/data3_ssd/RetinalDataset/ODIR-5K/label_valid.csv', 'w', encoding='utf-8', newline='') as f:
    csv_writer = csv.writer(f)
    csv_writer.writerows(content)

# %%
from faulthandler import disable


public = ['PM', 'MD', 'glaucoma', 'RVO', 'DR']
PM = [1,0,0,0,0]
MD = [0,1,0,0,0]
glaucoma = [0,0,1,0,0]
RVO = [0,0,0,1,0]
DR = [0,0,0,0,1]
content = []
disease = []
with open('/mnt/data3_ssd/RetinalDataset/TAOP-2021/test1_data_label.csv', 'r', encoding='utf-8') as f:
    csv_reader = csv.reader(f)
    for idx, c in enumerate(csv_reader):
        if idx == 0:
            content.append([c[2]] + public)
        else:
            name = c[2]
            if c[-1] == '1':
                disease = PM
            elif c[-1] == '2':
                disease = MD
            elif c[-1] == '3':
                disease = glaucoma
            elif c[-1] == '4':
                disease = RVO
            elif c[-1] == '5':
                disease = DR
            else:
                print('Error')
            content.append([name] + disease)
            
with open('/mnt/data3_ssd/RetinalDataset/TAOP-2021/label_valid.csv', 'w', encoding='utf-8', newline='') as f:
    csv_writer = csv.writer(f)
    csv_writer.writerows(content)

# %%
from faulthandler import disable


public = ['PM', 'MD', 'glaucoma', 'RVO', 'DR']
PM = [1,0,0,0,0]
MD = [0,1,0,0,0]
glaucoma = [0,0,1,0,0]
RVO = [0,0,0,1,0]
DR = [0,0,0,0,1]
content = []
disease = []
with open('/mnt/data3_ssd/RetinalDataset/TAOP-2021/train1_data_info.csv', 'r', encoding='utf-8') as f:
    csv_reader = csv.reader(f)
    for idx, c in enumerate(csv_reader):
        if idx == 0:
            content.append([c[2]] + public)
        else:
            name = c[2]
            if c[-1] == '1':
                disease = PM
            elif c[-1] == '2':
                disease = MD
            elif c[-1] == '3':
                disease = glaucoma
            elif c[-1] == '4':
                disease = RVO
            elif c[-1] == '5':
                disease = DR
            else:
                print('Error')
            content.append([name] + disease)
            
with open('/mnt/data3_ssd/RetinalDataset/TAOP-2021/label_train.csv', 'w', encoding='utf-8', newline='') as f:
    csv_writer = csv.writer(f)
    csv_writer.writerows(content)

# %%
public = ['Disease']
PM = [0]
MD = [1]
glaucoma = [2]
RVO = [3]
DR = [4]
content = []
disease = []
with open('/mnt/data3_ssd/RetinalDataset/TAOP-2021/train1_data_info.csv', 'r', encoding='utf-8') as f:
    csv_reader = csv.reader(f)
    for idx, c in enumerate(csv_reader):
        if idx == 0:
            content.append([c[2]] + public)
        else:
            name = c[2]
            if c[-1] == '1':
                disease = PM
            elif c[-1] == '2':
                disease = MD
            elif c[-1] == '3':
                disease = glaucoma
            elif c[-1] == '4':
                disease = RVO
            elif c[-1] == '5':
                disease = DR
            else:
                print('Error')
            content.append([name] + disease)
            
with open('/mnt/data3_ssd/RetinalDataset/TAOP-2021/label_train.csv', 'w', encoding='utf-8', newline='') as f:
    csv_writer = csv.writer(f)
    csv_writer.writerows(content)

# %%
public = ['Disease']
PM = [0]
MD = [1]
glaucoma = [2]
RVO = [3]
DR = [4]
content = []
disease = []
with open('/mnt/data3_ssd/RetinalDataset/TAOP-2021/test1_data_label.csv', 'r', encoding='utf-8') as f:
    csv_reader = csv.reader(f)
    for idx, c in enumerate(csv_reader):
        if idx == 0:
            content.append([c[2]] + public)
        else:
            name = c[2]
            if c[-1] == '1':
                disease = PM
            elif c[-1] == '2':
                disease = MD
            elif c[-1] == '3':
                disease = glaucoma
            elif c[-1] == '4':
                disease = RVO
            elif c[-1] == '5':
                disease = DR
            else:
                print('Error')
            content.append([name] + disease)
            
with open('/mnt/data3_ssd/RetinalDataset/TAOP-2021/label_valid.csv', 'w', encoding='utf-8', newline='') as f:
    csv_writer = csv.writer(f)
    csv_writer.writerows(content)

# %% [markdown]
# ## Multi-task

# %%
from models.encoder_decoder import get_task_head, get_task_loss
from models.build import build_hard_param_share_model

data = "TAOP, RFMiD"
decoder = get_task_head(data)
loss = get_task_loss(data)

# %%
decoder_params = []
for i in decoder:
    decoder_params += list(decoder[i].parameters())

# %%
from utils.model import count_parameters

num_params = 0
num_trainable_params = 0
decoder_params = []
for i in decoder:
    decoder_params += list(decoder[i].parameters())
    num_params_increment, num_trainable_params_increment = count_parameters(decoder[i])
    num_params += num_params_increment
    num_trainable_params += num_trainable_params_increment

# %% [markdown]
# # Datasets INFO

# %% [markdown]
# ## ODIR-5K (Multi-label)

# %%
import pandas as pd

path = '/mnt/data3_ssd/RetinalDataset/ODIR-5K/label_train.csv'
f_train = pd.read_csv(path)

path = '/mnt/data3_ssd/RetinalDataset/ODIR-5K/label_valid.csv'
f_valid = pd.read_csv(path)

stats = pd.concat([
    f_train.iloc[:,1:].sum(axis=0),
    f_valid.iloc[:,1:].sum(axis=0),
], axis = 1)

stats.columns = ['train', 'valid']
stats['all'] = (stats['train'] + stats['valid'])
stats['%'] = (stats['all'] / stats['all'].sum(axis=0) * 100).round(2)
stats['ratio'] = (stats['train']/stats['valid']).round(2)
#stats.loc['Total', :] = stats.sum(axis=0)
print(stats['train'].sum())
stats.loc['total'] = [stats['train'].sum(),stats['valid'].sum(),stats['all'].sum(),stats['%'].sum(),'-']

stats
# Out:
# 6814
#        train  valid   all       %  ratio
# N       2806    312  3118   41.26   8.99
# D       1623    178  1801   23.83   9.12
# G        294     32   326    4.31   9.19
# C        283     30   313    4.14   9.43
# A        255     25   280    3.71   10.2
# H        176     17   193    2.55  10.35
# M        242     26   268    3.55   9.31
# O       1135    123  1258   16.65   9.23
# total   6814    743  7557  100.00      -

# %%
import torch
weights = torch.tensor([2.2477, 3.8860, 21.4524, 22.2862, 24.7333, 35.8352, 26.0620, 5.5568])
len(weights)
# Out:
# 8

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

data = np.array(stats['train'][:-1].tolist())
labels = stats.index[:-1].tolist()

norm = plt.Normalize(data.min(), data.max())
norm_values = norm(data)
map_vir = cm.get_cmap(name='plasma')
color = map_vir(norm_values)

plt.figure(figsize=(20, 8), dpi=300)
plt.xticks(rotation=300)

sm = cm.ScalarMappable(cmap=map_vir,norm=norm)
plt.bar(range(len(data)), data, tick_label=labels, color = color)
plt.colorbar(sm)
plt.show()
# Out:
# /tmp/ipykernel_1204043/2895246900.py:18: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(sm)

# %% [markdown]
# ## TAOP (5 class)

# %%
import pandas as pd

path = '/mnt/data3_ssd/RetinalDataset/TAOP-2021/label_train.csv'
f_train = pd.read_csv(path)

path = '/mnt/data3_ssd/RetinalDataset/TAOP-2021/label_valid.csv'
f_valid = pd.read_csv(path)

disease = ['PM', 'MD', 'glaucoma', 'RVO', 'DR']

stats = pd.DataFrame()

stats['train'] = f_train['Disease'].value_counts()
stats['valid'] = f_valid['Disease'].value_counts()
stats['all'] = stats['train'] + stats['valid']
stats['%'] = (stats['all'] / stats['all'].sum(axis=0) * 100).round(2)
stats['ratio'] = (stats['train']/stats['valid']).round(1)
stats.loc['total'] = [stats['train'].sum(),stats['valid'].sum(),stats['all'].sum(),stats['%'].sum(),'-']
stats.rename(index={0: 'PM', 1: 'MD', 2: 'glaucoma', 3: 'RVO', 4: 'DR'}, inplace=True)

stats
# Out:
#           train  valid   all       % ratio
# glaucoma    647     50   697   21.14  12.9
# MD          647     66   713   21.63   9.8
# PM          642     75   717   21.75   8.6
# DR          641     58   699   21.20  11.1
# RVO         423     48   471   14.29   8.8
# total      3000    297  3297  100.01     -

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

data = np.array(stats['train'][:-1].tolist())
labels = stats.index[:-1].tolist()

norm = plt.Normalize(data.min(), data.max())
norm_values = norm(data)
map_vir = cm.get_cmap(name='plasma')
color = map_vir(norm_values)

plt.figure(figsize=(20, 8), dpi=300)
plt.xticks(rotation=0)

sm = cm.ScalarMappable(cmap=map_vir,norm=norm)
plt.bar(range(len(data)), data, tick_label=labels, color = color)
plt.colorbar(sm)
plt.show()
# Out:
# /tmp/ipykernel_1381622/2482435202.py:18: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(sm)

# %%
stats.to_csv('stats.csv', index = False)

# %% [markdown]
# ## RFMiD (Multi-label)

# %%
import pandas as pd

path = '/mnt/data3_ssd/RetinalDataset/RFMiD/RFMiD_Training_Labels.csv'
f_train = pd.read_csv(path)

path = '/mnt/data3_ssd/RetinalDataset/RFMiD/RFMiD_Validation_Labels.csv'
f_valid = pd.read_csv(path)

f_train['OTHER'] = (f_train.iloc[:, 29:].sum(axis=1)>0.5).astype(int)
f_valid['OTHER'] = (f_valid.iloc[:, 29:].sum(axis=1)>0.5).astype(int)
#f_train = f_train['OTHER'].sum()
f_train = f_train.drop(['CWS', 'CB', 'ODPM', 'PRH', 'MNF', 'HR', 'CRAO', 'TD', 'CME', 'PTCR', 'CF', 'VH', 'MCA', 'VS', 'BRAO', 'PLQ', 'HPED', 'CL'], axis=1)
f_valid = f_valid.drop(['CWS', 'CB', 'ODPM', 'PRH', 'MNF', 'HR', 'CRAO', 'TD', 'CME', 'PTCR', 'CF', 'VH', 'MCA', 'VS', 'BRAO', 'PLQ', 'HPED', 'CL'], axis=1)

f_train.to_csv('label_train.csv', index=False)
f_valid.to_csv('label_valid.csv', index=False)

stats = pd.concat([
    f_train.iloc[:,1:].sum(axis=0),
    f_valid.iloc[:,1:].sum(axis=0),
], axis = 1)

stats.columns = ['train', 'valid']
stats['all'] = (stats['train'] + stats['valid'])
stats['%'] = (stats['all'] / stats['all'].sum(axis=0) * 100).round(2)
stats['ratio'] = (stats['train']/stats['valid']).round(2)
stats.loc['total'] = [stats['train'].sum(),stats['valid'].sum(),stats['all'].sum(),stats['%'].sum(),'-']
stats
# Out:
#               train  valid   all       % ratio
# Disease_Risk   1519    506  2025   42.31   3.0
# DR              376    132   508   10.61  2.85
# ARMD            100     38   138    2.88  2.63
# MH              317    102   419    8.75  3.11
# DN              138     46   184    3.84   3.0
# MYA             101     34   135    2.82  2.97
# BRVO             73     23    96    2.01  3.17
# TSLN            186     65   251    5.24  2.86
# ERM              14      7    21    0.44   2.0
# LS               47     17    64    1.34  2.76
# MS               15      5    20    0.42   3.0
# CSR              37     11    48    1.00  3.36
# ODC             282     72   354    7.40  3.92
# CRVO             28      8    36    0.75   3.5
# TV                6      2     8    0.17   3.0
# AH               16      4    20    0.42   4.0
# ODP              65     26    91    1.90   2.5
# ODE              58     21    79    1.65  2.76
# ST                5      4     9    0.19  1.25
# ...

# %%
import torch
weights = torch.tensor([1.264, 5.106, 19.2, 6.057, 13.913, 19.01, 26.301, 10.323, 137.143, 40.851, 128.0, 51.892, 6.809, 68.571, 320.0, 120.0, 29.538, 33.103, 384.0, 112.941, 174.545, 137.143, 44.651, 60.0, 128.0, 87.273, 174.545, 320.0, 56.471])
weights.shape
# Out:
# torch.Size([29])

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

map_vir = cm.get_cmap(name='plasma')

data = np.array(stats['train'][:-1].tolist() + [401])
labels = stats.index[:-1].tolist() + ['NORMAL']

norm = plt.Normalize(data.min(), data.max())
norm_values = norm(data)
map_vir = cm.get_cmap(name='plasma')
color = map_vir(norm_values)

plt.figure(figsize=(20, 8), dpi=300)
plt.xticks(rotation=300)

sm = cm.ScalarMappable(cmap=map_vir,norm=norm)
plt.bar(range(len(data)), data, tick_label=labels, color = color)
plt.colorbar(sm)
plt.show()
# Out:
# /tmp/ipykernel_1204043/4212925054.py:20: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(sm)

# %%
len(f_train[f_train.iloc[:, 1:].sum(axis=1)<0.5])
# Out:
# 401

# %% [markdown]
# ## APTOS (5 class)

# %%
import pandas as pd
import os
from sklearn.model_selection import train_test_split

path = '/mnt/data3_ssd/RetinalDataset/APTOS/label_train.csv'
f_train = pd.read_csv(path)

path = '/mnt/data3_ssd/RetinalDataset/APTOS/label_valid.csv'
f_valid = pd.read_csv(path)

diagnosis = ['0', '1', '2', '3', '4']

stats = pd.DataFrame()

stats['train'] = f_train['diagnosis'].value_counts()
stats['valid'] = f_valid['diagnosis'].value_counts()
stats['all'] = stats['train'] + stats['valid']
stats['%'] = (stats['all'] / stats['all'].sum(axis=0) * 100).round(2)
stats['ratio'] = (stats['train']/stats['valid']).round(1)
stats.loc['total'] = [stats['train'].sum(),stats['valid'].sum(),stats['all'].sum(),stats['%'].sum(),'-']
stats.rename(index={0: 'Grade 0', 1: 'Grade 1', 2: 'Grade 2', 3: 'Grade 3', 4: 'Grade 4'}, inplace=True)

stats
# Out:
#          train  valid   all       % ratio
# Grade 0   1622    183  1805   49.29   8.9
# Grade 2    900     99   999   27.28   9.1
# Grade 1    330     40   370   10.10   8.2
# Grade 4    266     29   295    8.06   9.2
# Grade 3    177     16   193    5.27  11.1
# total     3295    367  3662  100.00     -

# %%
stats.to_csv('stats.csv', index = False)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

data = np.array(stats['train'][:-1].tolist())
labels = stats.index[:-1].tolist()

norm = plt.Normalize(data.min(), data.max())
norm_values = norm(data)
map_vir = cm.get_cmap(name='plasma')
color = map_vir(norm_values)

plt.figure(figsize=(20, 8), dpi=300)
plt.xticks(rotation=0)

sm = cm.ScalarMappable(cmap=map_vir,norm=norm)
plt.bar(range(len(data)), data, tick_label=labels, color = color)
plt.colorbar(sm)
plt.show()
# Out:
# /tmp/ipykernel_1381622/2482435202.py:18: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(sm)

# %% [markdown]
# ## Kaggle (5 class)

# %%
import pandas as pd
import os
from sklearn.model_selection import train_test_split

path = '/mnt/data3_ssd/RetinalDataset/Kaggle/trainLabels.csv'
#f = pd.read_csv(path)
#f_train, f_valid = train_test_split(f, test_size = 0.1, shuffle=True)

f_train = pd.read_csv(path)

path = '/mnt/data3_ssd/RetinalDataset/Kaggle/label_test.csv'
f_valid = pd.read_csv(path)

stats = pd.DataFrame()

stats['train'] = f_train['level'].value_counts()
stats['valid'] = f_valid['level'].value_counts()
stats['all'] = stats['train'] + stats['valid']
stats['%'] = (stats['all'] / stats['all'].sum(axis=0) * 100).round(2)
stats['ratio'] = (stats['train']/stats['valid']).round(1)
stats.loc['total'] = [stats['train'].sum(),stats['valid'].sum(),stats['all'].sum(),stats['%'].sum(),'-']
stats.rename(index={0: 'Grade 0', 1: 'Grade 1', 2: 'Grade 2', 3: 'Grade 3', 4: 'Grade 4'}, inplace=True)

stats
# Out:
#          train  valid    all       % ratio
# Grade 0  25810  39533  65343   73.67   0.7
# Grade 2   5292   7861  13153   14.83   0.7
# Grade 1   2443   3762   6205    7.00   0.6
# Grade 3    873   1214   2087    2.35   0.7
# Grade 4    708   1206   1914    2.16   0.6
# total    35126  53576  88702  100.01     -

# %%
stats.to_csv('stats.csv', index = False)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

data = np.array(stats['train'][:-1].tolist())
labels = stats.index[:-1].tolist()

norm = plt.Normalize(data.min(), data.max())
norm_values = norm(data)
map_vir = cm.get_cmap(name='plasma')
color = map_vir(norm_values)

plt.figure(figsize=(20, 8), dpi=300)
plt.xticks(rotation=0)

sm = cm.ScalarMappable(cmap=map_vir,norm=norm)
plt.bar(range(len(data)), data, tick_label=labels, color = color)
plt.colorbar(sm)
plt.show()
# Out:
# /tmp/ipykernel_1381622/2482435202.py:18: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(sm)

# %% [markdown]
# ## KaggleDR+ (Multi-label)

# %%
path = '/mnt/data3_ssd/RetinalDataset/KaggleDR+/kaggle_DR+_directory_index.csv' # 53 class
f = pd.read_csv(path)
loss = ['disc_glory', 'si_eye', 'hypertensionIII', 'choroidal_osteoma',
       'choroidal_hemangioma', 'Coats', 'retina_aneurysm', 'disc_edm',
       'disc_AION', 'disc_papillitis', 'CRAO', 'path_myphia_miman', 'CRVO',
       'disc_atrophy', 'amotio', 'macula_csc', 'BRAO', 'VH',
       'peripheral_degeneration', 'choroid_coloboma', 'path_myphia_banpian',
       'disc_other', 'RP', 'macula_GA', 'macula_hole', 'macula_CNV']
f['OTHER'] = (f.loc[:, loss].sum(axis=1)>0.5).astype(int)
f = f.drop(loss, axis=1) # 28 class

f_train, f_valid = train_test_split(f, test_size = 0.1, shuffle=True)
f_train.to_csv('label_train.csv', index=False)
f_valid.to_csv('label_valid.csv', index=False)

# %%
import pandas as pd
import os
from sklearn.model_selection import train_test_split

path = '/mnt/data3_ssd/RetinalDataset/KaggleDR+/label_train.csv'
f_train = pd.read_csv(path)

path = '/mnt/data3_ssd/RetinalDataset/KaggleDR+/label_valid.csv'
f_valid = pd.read_csv(path)

stats = pd.concat([
    f_train.iloc[:,1:].sum(axis=0),
    f_valid.iloc[:,1:].sum(axis=0),
], axis = 1)

stats.columns = ['train', 'valid']
stats['all'] = (stats['train'] + stats['valid'])
stats['%'] = (stats['all'] / stats['all'].sum(axis=0) * 100).round(2)
stats['ratio'] = (stats['train']/stats['valid']).round(2)
stats.loc['total'] = [stats['train'].sum(),stats['valid'].sum(),stats['all'].sum(),stats['%'].sum(),'-']
stats
# Out:
#                       train  valid    all       %  ratio
# normal                 8862    971   9833   10.50   9.13
# hypertensionI         14344   1603  15947   17.03   8.95
# NPDRIII                 563     48    611    0.65  11.73
# myopia                26884   3025  29909   31.95   8.89
# NPDRII                 4283    446   4729    5.05    9.6
# disc_glaucoma          3518    422   3940    4.21   8.34
# macula_small_drusen    9676   1026  10702   11.43   9.43
# macula_other            318     34    352    0.38   9.35
# path_myphia_macula      467     60    527    0.56   7.78
# blur                   7681    882   8563    9.15   8.71
# macula_em               342     36    378    0.40    9.5
# hypertensionII          874     98    972    1.04   8.92
# NPDRI                  2415    267   2682    2.86   9.04
# poor_quality            514     54    568    0.61   9.52
# less_elatic_artery      242     20    262    0.28   12.1
# ...

# %%
index = '38104_left.jpeg'

if not os.path.exists(f'/mnt/data3_ssd/RetinalDataset/Kaggle/test/{index}'):
    print('not in test')
    print(os.path.exists(f'/mnt/data3_ssd/RetinalDataset/Kaggle/train/{index}'))
# Out:
# not in test
# True

# %% [markdown]
# ## AMD (0-1 classification)

# %%
import pandas as pd

path = '/mnt/data3_ssd/RetinalDataset/iChallenge-AMD/Training400/label_train.csv'
f_train = pd.read_csv(path)

path = '/mnt/data3_ssd/RetinalDataset/iChallenge-AMD/Training400/label_valid.csv'
f_valid = pd.read_csv(path)

stats = pd.DataFrame()

stats['train'] = f_train['Disease'].value_counts()
stats['valid'] = f_valid['Disease'].value_counts()
stats['all'] = stats['train'] + stats['valid']
stats['%'] = (stats['all'] / stats['all'].sum(axis=0) * 100).round(2)
stats['ratio'] = (stats['train']/stats['valid']).round(1)
stats.loc['total'] = [stats['train'].sum(),stats['valid'].sum(),stats['all'].sum(),stats['%'].sum(),'-']

stats
# Out:
#        train  valid  all       % ratio
# 0        249     62  311   77.75   4.0
# 1         72     17   89   22.25   4.2
# total    321     79  400  100.00     -

# %%
from PIL import Image

img = Image.open('/mnt/data3_ssd/RetinalDataset/iChallenge-AMD/Training400/resized/A0001.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %% [markdown]
# ## DDR (6 class)

# %%
import pandas as pd

path = '/mnt/data3_ssd/RetinalDataset/DDR/DDR-dataset/DR_grading/label_train.csv'
f_train = pd.read_csv(path)

path = '/mnt/data3_ssd/RetinalDataset/DDR/DDR-dataset/DR_grading/label_valid.csv'
f_valid = pd.read_csv(path)

path = '/mnt/data3_ssd/RetinalDataset/DDR/DDR-dataset/DR_grading/label_test.csv'
f_test = pd.read_csv(path)

stats = pd.DataFrame()

stats['train'] = f_train['Disease'].value_counts()
stats['valid'] = f_valid['Disease'].value_counts()
stats['test'] = f_valid['Disease'].value_counts()
stats['all'] = stats['train'] + stats['valid'] + stats['test']
stats['%'] = (stats['all'] / stats['all'].sum(axis=0) * 100).round(2)
stats['ratio'] = (stats['train']/stats['valid']).round(1)
stats.loc['total'] = [stats['train'].sum(),stats['valid'].sum(),stats['test'].sum(),stats['all'].sum(),stats['%'].sum(),'-']

stats
# Out:
#        train  valid  test    all       % ratio
# 0       3133   1253  1253   5639   45.84   2.5
# 2       2238    895   895   4028   32.75   2.5
# 5        575    230   230   1035    8.41   2.5
# 4        456    182   182    820    6.67   2.5
# 1        315    126   126    567    4.61   2.5
# 3        118     47    47    212    1.72   2.5
# total   6835   2733  2733  12301  100.00     -

# %%
from PIL import Image

img = Image.open('/mnt/data3_ssd/RetinalDataset/DDR/DDR-dataset/DR_grading/resized/007-0004-000.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %% [markdown]
# ## LAG (0-1 classification)

# %%
import pandas as pd

path = '/mnt/data3_ssd/RetinalDataset/LAG/dataset/label_train.csv'
f_train = pd.read_csv(path)

path = '/mnt/data3_ssd/RetinalDataset/LAG/dataset/label_valid.csv'
f_valid = pd.read_csv(path)


stats = pd.DataFrame()

stats['train'] = f_train['Disease'].value_counts()
stats['valid'] = f_valid['Disease'].value_counts()
stats['all'] = stats['train'] + stats['valid']
stats['%'] = (stats['all'] / stats['all'].sum(axis=0) * 100).round(2)
stats['ratio'] = (stats['train']/stats['valid']).round(1)
stats.loc['total'] = [stats['train'].sum(),stats['valid'].sum(),stats['all'].sum(),stats['%'].sum(),'-']

stats
# Out:
#        train  valid   all       % ratio
# 0       2515    628  3143   64.75   4.0
# 1       1369    342  1711   35.25   4.0
# total   3884    970  4854  100.00     -

# %%
from PIL import Image

img = Image.open('/mnt/data3_ssd/RetinalDataset/LAG/dataset/valid/0006.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %% [markdown]
# ## PALM (0-1 classification)

# %%
import pandas as pd

path = '/mnt/data3_ssd/RetinalDataset/iChallenge-PM/label_train.csv'
f_train = pd.read_csv(path)

path = '/mnt/data3_ssd/RetinalDataset/iChallenge-PM/label_valid.csv'
f_valid = pd.read_csv(path)


stats = pd.DataFrame()

stats['train'] = f_train['Disease'].value_counts()
stats['valid'] = f_valid['Disease'].value_counts()
stats['all'] = stats['train'] + stats['valid']
stats['%'] = (stats['all'] / stats['all'].sum(axis=0) * 100).round(2)
stats['ratio'] = (stats['train']/stats['valid']).round(1)
stats.loc['total'] = [stats['train'].sum(),stats['valid'].sum(),stats['all'].sum(),stats['%'].sum(),'-']

stats
# Out:
#        train  valid  all      % ratio
# 1        340     84  424   53.0   4.0
# 0        301     75  376   47.0   4.0
# total    641    159  800  100.0     -

# %%
from PIL import Image

img = Image.open('/mnt/data3_ssd/RetinalDataset/iChallenge-PM/resized/H0001.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %% [markdown]
# ## REFUGE (0-1 classification)

# %%
import pandas as pd

path = '/mnt/data3_ssd/RetinalDataset/REFUGE/label_train.csv'
f_train = pd.read_csv(path)

path = '/mnt/data3_ssd/RetinalDataset/REFUGE/label_valid.csv'
f_valid = pd.read_csv(path)

path = '/mnt/data3_ssd/RetinalDataset/REFUGE/label_test.csv'
f_test = pd.read_csv(path)

stats = pd.DataFrame()

stats['train'] = f_train['Disease'].value_counts()
stats['valid'] = f_valid['Disease'].value_counts()
stats['test'] = f_valid['Disease'].value_counts()
stats['all'] = stats['train'] + stats['valid'] + stats['test']
stats['%'] = (stats['all'] / stats['all'].sum(axis=0) * 100).round(2)
stats['ratio'] = (stats['train']/stats['valid']).round(1)
stats.loc['total'] = [stats['train'].sum(),stats['valid'].sum(),stats['test'].sum(),stats['all'].sum(),stats['%'].sum(),'-']

stats
# Out:
#        train  valid  test   all      % ratio
# 0        360    360   360  1080   90.0   1.0
# 1         40     40    40   120   10.0   1.0
# total    400    400   400  1200  100.0     -

# %%
from PIL import Image

img = Image.open('/mnt/data3_ssd/RetinalDataset/REFUGE/resized/g0001.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %% [markdown]
# # Try

# %%
import torch
from torch.utils.data import Dataset, DataLoader

dataset = torch.tensor([0, 1, 2, 3])
dataloader = DataLoader(dataset, batch_size=3, shuffle=True)
iterloader = iter(dataloader)

dataset2 = torch.tensor([4, 5, 6, 7])
dataloader2 = DataLoader(dataset2, batch_size=2, shuffle=True)
iterloader2 = iter(dataloader2)

def get_batch(iterloader, dataloader):
    try:
        batch = next(iterloader)
    except StopIteration:
        print('Loop')
        iterloader = iter(dataloader)
        batch = next(iterloader)
    return iterloader

for i in range(10):
    print(get_batch(iterloader, dataloader))
    #print(get_batch(iterloader2, dataloader2))
# Out:
# tensor([3, 1, 2])
# tensor([0])
# Loop
# tensor([2, 3, 0])
# Loop
# tensor([2, 3, 1])
# Loop
# tensor([3, 0, 1])
# Loop
# tensor([1, 0, 2])
# Loop
# tensor([0, 3, 2])
# Loop
# tensor([0, 3, 2])
# Loop
# tensor([0, 3, 1])
# Loop
# tensor([0, 2, 3])

# %%
for i in dataloader:
    print(i)
# Out:
# tensor([3, 1])
# tensor([0, 2])

# %%
data = {}

dataset = torch.tensor([0, 1, 2, 3])
dataloader = DataLoader(dataset, batch_size=3, shuffle=True)

data['data1'] = {}
data['data1']['dataloader'] = dataloader
data['data1']['iterloader'] = iter(dataloader)

dataset2 = torch.tensor([4, 5, 6, 7])
dataloader2 = DataLoader(dataset2, batch_size=3, shuffle=True)

data['data2'] = {}
data['data2']['dataloader'] = dataloader2
data['data2']['iterloader'] = iter(dataloader2)



def get_batch(data):
    try:
        batch = next(data['iterloader'])
    except StopIteration:
        print('Loop')
        data['iterloader'] = iter(data['dataloader'])
        batch = next(data['iterloader'])
    return batch

class test(object):
    def __init__(self, data):
        self.data = data
    def test(self):
        for i in range(10):
            print('data1:')
            batch = get_batch(self.data['data1'])
            print(batch)

            print('data2:')
            batch = get_batch(self.data['data2'])
            print(batch)
            
            print()

a = test(data)
a.test()
# Out:
# data1:
# tensor([3, 2, 1])
# data2:
# tensor([4, 6, 7])
#
# data1:
# tensor([0])
# data2:
# tensor([5])
#
# data1:
# Loop
# tensor([1, 3, 2])
# data2:
# Loop
# tensor([7, 4, 6])
#
# data1:
# tensor([0])
# data2:
# tensor([5])
#
# data1:
# Loop
# tensor([1, 2, 0])
# data2:
# Loop
# tensor([6, 5, 7])
#
# data1:
# tensor([3])
# data2:
# tensor([4])
#
# data1:
# Loop
# tensor([3, 1, 2])
# data2:
# Loop
# tensor([4, 5, 7])
#
# data1:
# tensor([0])
# data2:
# tensor([6])
#
# data1:
# Loop
# tensor([3, 0, 1])
# data2:
# Loop
# tensor([6, 4, 5])
#
# data1:
# tensor([2])
# data2:
# tensor([7])

# %%
import numpy as np
weights = [1,2]
weights = np.array(weights, dtype=np.float32)

# %% [markdown]
# # Latent Space

# %%
from data.dataset import TrainDataset, ValidDataset
import numpy as np
from matplotlib import pyplot as plt
from torchvision import transforms
import torch

# %%
a = ValidDataset('TAOP')
img_size = 256
transform = transforms.Compose([transforms.Resize((img_size, img_size)), transforms.PILToTensor()])

xfile = transform(a[0]['image'].convert("L")).reshape([1, img_size*img_size])
yfile=[1]

for i in range(len(a)-1):
    xfile = torch.cat((xfile, transform(a[i+1]['image'].convert("L")).reshape([1, img_size*img_size])), 0)
    yfile.append(a[i+1]['landmarks'][0].tolist())

# %%
img = xfile[0].reshape(img_size, img_size)
plt.imshow(img)
plt.show()

# %%
from utils.tsne import tsne, pca_torch, x2p_torch, Hbeta_torch

X = xfile.float()
labels = yfile

assert(len(X[:, 0])==len(X[:,1]))
assert(len(X)==len(labels))

with torch.no_grad():
    Y = tsne(X, 2, 50, 30.0)
# Out:
# Preprocessing the data using PCA...

# %%
plt.scatter(Y[:, 0], Y[:, 1], 20, labels)
plt.show()

# %% [markdown]
# # Class-aware Sampling

# %%
from data.sampler import ImbalancedDatasetSampler
from data.dataset import TrainDataset, ValidDataset, get_train_transforms
import torch

transform = get_train_transforms(224)
a = TrainDataset('Kaggle', transform=transform)


train_loader = torch.utils.data.DataLoader(
    a,
    sampler=ImbalancedDatasetSampler(a),
    batch_size=1,
)

# %%
list = []

for i, sample in enumerate(train_loader):
    img = sample['image']
    gt = sample['landmarks']
    list.append(gt[0][0].tolist())

# %%
dict = {}
for key in list:
    dict[key] = dict.get(key, 0) + 1
print(dict)
# Out:
# {1: 7115, 0: 7052, 4: 6970, 2: 7058, 3: 6931}

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

def draw_from_dict(dicdata,RANGE, heng=0):
    #dicdata：字典的数据。
    #RANGE：截取显示的字典的长度。
    #heng=0，代表条状图的柱子是竖直向上的。heng=1，代表柱子是横向的。考虑到文字是从左到右的，让柱子横向排列更容易观察坐标轴。
    by_value = sorted(dicdata.items(),key = lambda item:item[1],reverse=True)
    x = []
    y = []
    for d in by_value:
        x.append(d[0])
        y.append(d[1])
    if heng == 0:
        plt.bar(x[0:RANGE], y[0:RANGE])
        plt.show()
        return 
    elif heng == 1:
        plt.barh(x[0:RANGE], y[0:RANGE])
        plt.show()
        return 
    else:
        return "error"

draw_from_dict(dict,5)

# %%
from data.sampler import MultilabelBalancedRandomSampler
from data.dataset import TrainDataset, ValidDataset, get_train_transforms
import torch

# %%
import pandas as pd
from data.sampler import ImbalancedDatasetSampler
from data.dataset import TrainDataset, ValidDataset, get_train_transforms
import torch

transform = get_train_transforms(224)
a = TrainDataset('Kaggle', transform=transform)
a.get_labels()

df = pd.DataFrame()
df["label"] = a.get_labels()

df.index = list(range(len(a)))
df = df.sort_index()

label_to_count = df["label"].value_counts()

weights = 1.0 / label_to_count[df["label"]]

weights = torch.DoubleTensor(weights.to_list())

# %%
dict = {}
for key in df['label']:
    dict[key] = dict.get(key, 0) + 1
print(dict)
# Out:
# {0: 25810, 1: 2443, 2: 5292, 4: 708, 3: 873}

# %%
import pandas as pd
from data.sampler import ImbalancedDatasetSampler, MultilabelBalancedRandomSampler
from data.dataset import TrainDataset, ValidDataset, get_train_transforms
import torch

transform = get_train_transforms(224)
b = TrainDataset('ODIR-5K', transform=transform)

loader = torch.utils.data.DataLoader(
    b,
    sampler=MultilabelBalancedRandomSampler(b.get_labels()),
    batch_size=1,
)

# %%
list = []

for i, sample in enumerate(loader):
    img = sample['image']
    gt = sample['landmarks']
    list.append(gt[0].tolist())

# %%
import numpy as np

list2array = np.array(list)

# %%
np.sum(list2array,axis = 0)
# Out:
# array([957., 957., 957., 957., 957., 957., 957., 957.])

# %% [markdown]
# # LibMTL

# %%
from models.encoder_decoder import Encoder, get_task_head
import torch.nn as nn
from utils.info import terminal_msg, epic_start, get_device
from models.resnet import resnet50
import torch
from models.build import build_MMoE_model, build_CGC_model, build_MTAN_model, build_DSelectK_model
import numpy as np

# %%
class myargs():
    def __init__(self, data, lr):
        super(myargs, self).__init__()
        self.data = data
        self.lr = lr
        self.mode = 'train'

os.environ['CUDA_VISIBLE_DEVICES'] = '0'
a = myargs("ODIR-5K, TAOP, RFMiD, APTOS, Kaggle, DR+", 0.1)
model =build_DSelectK_model(args=a).cuda()

# %%
model
# Out:
# DSelectK(
#   (encoder): ModuleList(
#     (0): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
data = "ODIR-5K, TAOP, RFMiD, APTOS, Kaggle, DR+"
data_dict = data.split(", ")

# %%
input = torch.randn([2, 3, 224, 224]).cuda()
img = input
head = 'TAOP'
model(img=input, head='TAOP')[1].shape

experts_shared_rep = torch.stack([e(img) for e in model.encoder]) # torch.Size([3, batch, 2048, 7, 7])

selector = model.gate_specific[head](torch.flatten(img, start_dim=1)) # torch.Size([batch, 3])
gate_rep = torch.einsum('ij..., ji -> j...', experts_shared_rep, selector) # torch.Size([batch, 2048, 7, 7])
print(gate_rep.shape)
gate_rep = model._prepare_rep(gate_rep, head, same_rep=False) # torch.Size([batch, 2048, 7, 7])
print(gate_rep.shape)
pred = model.decoder[head](gate_rep)
# Out:
# torch.Size([2, 2048, 7, 7])
# torch.Size([2, 2048, 7, 7])

# %%
list(model.gate_specific['TAOP'].cpu().parameters())[0][0]
# Out:
# tensor([-5.5526e-04, -9.2088e-05, -2.2606e-03,  ..., -2.0327e-03,
#         -1.0305e-04,  2.0786e-03], grad_fn=<SelectBackward0>)

# %%
model.gate_specific[head](torch.flatten(img, start_dim=1))
# Out:
# tensor([[0.3507, 0.3647, 0.2845],
#         [0.2501, 0.5842, 0.1657]], device='cuda:0', grad_fn=<SoftmaxBackward0>)

# %%
model = build_CGC_model(args=a).cuda()

# %%
input = torch.randn([2, 3, 224, 224]).cuda()

img = input
head = 'TAOP'
#model(img=input, head='TAOP')[0].shape

experts_shared_rep = torch.stack([e(img) for e in model.experts_shared]) # [share_exp, batch, 2048, 7, 7]
experts_specific_rep = torch.stack([e(img) for e in model.experts_specific[head]]) # [specific_exp, batch, 2048, 7, 7]
selector = model.gate_specific[head](torch.flatten(img, start_dim=1)) # [batch, share + specific]
gate_rep = torch.einsum('ij..., ji -> j...', torch.cat([experts_shared_rep, experts_specific_rep], dim=0), selector) # [batch, 2048, 7, 7]
gate_rep = model._prepare_rep(gate_rep, head, same_rep=False) # [batch, 2048, 7, 7]
pred = model.decoder[head](gate_rep)

# %%
class myargs():
    def __init__(self, data, lr):
        super(myargs, self).__init__()
        self.data = data
        self.lr = lr

a = myargs("ODIR-5K, TAOP, RFMiD, APTOS, Kaggle, DR+", 0.1)
model = build_MTAN_model(args=a).cuda()

# %%
input = torch.randn([2, 3, 224, 224]).cuda()

img = input
head = 'TAOP'

model(img, head)[1]
# Out:
# tensor([-0.5796, -0.3827,  0.0216,  0.4079,  0.0456], device='cuda:0',
#        grad_fn=<SelectBackward0>)
